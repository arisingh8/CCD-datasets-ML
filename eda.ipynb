# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("data/CCD-IDSv1/intrusion_dataset.csv", 
                    names=["Dur", "Runtime", "Idle", "Mean", "Stddev", "Sum", "Min", "Max", "Proto", "Cause", "Pkts", "Spkts", "Dpkts", "Bytes", "Sbytes", "Dbytes", "Load", "Sload", "Dload", "Rate", "Srate", "Drate", "Offset", "Smeansz", "Dmeansz", "Attack"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7608983 entries, 0 to 7608982
# Data columns (total 26 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   Dur      float64
#  1   Runtime  float64
#  2   Idle     float64
#  3   Mean     float64
#  4   Stddev   float64
#  5   Sum      float64
#  6   Min      float64
#  7   Max      float64
#  8   Proto    int64
#  9   Cause    int64
#  10  Pkts     int64
#  11  Spkts    int64
#  12  Dpkts    int64
#  13  Bytes    int64
#  14  Sbytes   int64
#  15  Dbytes   int64
#  16  Load     float64
#  17  Sload    float64
#  18  Dload    float64
#  19  Rate     float64
#  20  Srate    float64
#  21  Drate    float64
#  22  Offset   int64
#  23  Smeansz  float64
#  24  Dmeansz  float64
#  25  Attack   int64
# dtypes: float64(16), int64(10)
# memory usage: 1.5 GB

# %%
df.head()
# Out:
#         Dur   Runtime          Idle      Mean  Stddev       Sum       Min  \
# 0  0.200100  0.200100  1.613614e+09  0.200100     0.0  0.200100  0.200100
# 1  0.026048  0.026048  1.613614e+09  0.026048     0.0  0.026048  0.026048
# 2  0.197193  0.197193  1.613614e+09  0.197193     0.0  0.197193  0.197193
# 3  0.021949  0.021949  1.613614e+09  0.021949     0.0  0.021949  0.021949
# 4  0.017954  0.017954  1.613614e+09  0.017954     0.0  0.017954  0.017954
#
#         Max  Proto  Cause  ...          Load         Sload         Dload  \
# 0  0.200100      0      0  ...      0.000000      0.000000      0.000000
# 1  0.026048      0      0  ...  37469.285156  37469.285156      0.000000
# 2  0.197193      0      1  ...      0.000000      0.000000      0.000000
# 3  0.021949      0      0  ...  70709.367188  42279.828125  28429.541016
# 4  0.017954      1      0  ...      0.000000      0.000000      0.000000
#
#          Rate      Srate      Drate  Offset  Smeansz  Dmeansz  Attack
# ...

# %%
df["Stddev"].describe()
# Out:
# count    7608983.0
# mean           0.0
# std            0.0
# min            0.0
# 25%            0.0
# 50%            0.0
# 75%            0.0
# max            0.0
# Name: Stddev, dtype: float64

# %%
attack = df["Attack"].value_counts().rename({0: "Normal", 1: "Attack"})
print(attack)

attack.plot(kind="pie", ylabel="", title="Behavior Type", autopct='%1.1f%%', startangle=90)
# Out:
# Attack    7163820
# Normal     445163
# Name: Attack, dtype: int64
# <AxesSubplot: title={'center': 'Behavior Type'}>

# %%
print(df['Dur'].describe())
df["Dur"].plot(kind="hist", title="Record Duration")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Dur, dtype: float64
# <AxesSubplot: title={'center': 'Record Duration'}, ylabel='Frequency'>

# %%
print(df['Runtime'].describe())
df["Runtime"].plot(kind="hist", title="Runtime")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Runtime, dtype: float64
# <AxesSubplot: title={'center': 'Runtime'}, ylabel='Frequency'>

# %%
print(df['Idle'].describe())
df["Idle"].plot(kind="hist", title="Idle Time")
# Out:
# count    7.608983e+06
# mean     1.613509e+09
# std      2.611780e+04
# min      1.613503e+09
# 25%      1.613503e+09
# 50%      1.613503e+09
# 75%      1.613503e+09
# max      1.613614e+09
# Name: Idle, dtype: float64
# <AxesSubplot: title={'center': 'Idle Time'}, ylabel='Frequency'>

# %%
print(df['Mean'].describe())
df["Mean"].plot(kind="hist", title="Mean Duration")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Mean, dtype: float64
# <AxesSubplot: title={'center': 'Mean Duration'}, ylabel='Frequency'>

# %%
print(df['Sum'].describe())
df["Sum"].plot(kind="hist", title="Total Durations")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Sum, dtype: float64
# <AxesSubplot: title={'center': 'Total Durations'}, ylabel='Frequency'>

# %%
print(df['Min'].describe())
df["Min"].plot(kind="hist", title="Minimum Duration")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Min, dtype: float64
# <AxesSubplot: title={'center': 'Minimum Duration'}, ylabel='Frequency'>

# %%
print(df['Max'].describe())
df["Max"].plot(kind="hist", title="Maximum Duration")
# Out:
# count    7.608983e+06
# mean     1.606426e+00
# std      1.432881e+00
# min      0.000000e+00
# 25%      1.200000e-05
# 50%      1.820704e+00
# 75%      2.922707e+00
# max      5.000011e+00
# Name: Max, dtype: float64
# <AxesSubplot: title={'center': 'Maximum Duration'}, ylabel='Frequency'>

# %%
print(df["Proto"].value_counts())

df["Proto"].value_counts().plot(kind="pie", ylabel="", title="Protocol", startangle=90)
# Out:
# 0    7212928
# 1     209986
# 2     101557
# 5      64982
# 3      10634
# 4       3073
# 6       2958
# 7       2832
# 8         33
# Name: Proto, dtype: int64
# <AxesSubplot: title={'center': 'Protocol'}>

# %%
print(df["Cause"].value_counts())

df["Cause"].value_counts().plot(kind="pie", ylabel="", title="Cause", startangle=90)
# Out:
# 2    4162021
# 0    3094298
# 1     352664
# Name: Cause, dtype: int64
# <AxesSubplot: title={'center': 'Cause'}>

# %%
sns.heatmap(df.corr(), yticklabels=True)
# Out:
# <AxesSubplot: >

# %%
sns.heatmap(df[['Dur', 'Runtime', 'Mean', 'Sum', 'Min', 'Max']].corr(), vmin=0.8, vmax=1.0)
# Out:
# <AxesSubplot: >

# %%
len(df)
# Out:
# 7608983
